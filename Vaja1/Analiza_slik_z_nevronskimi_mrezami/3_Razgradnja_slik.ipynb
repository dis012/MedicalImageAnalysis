# %% [markdown]
# # Analiza slik z nevronskimi mrežami
#
# ## 3. Razgradnja slik z nevronskimi mrežami
#
# ### Motivacija
#
# Razgradnjo MRI slik pri bolnikih z multiplo sklerozo je klinično motivirana. Preko razgradnje lahko izvajamo meritve razgrajenih struktur, kot so prostornina bele in sive možganovine, prostorina in število patoloških lezij, ipd. Te meritve, npr. prostornina zdravih možganskih struktur in patoloških lezij odražata stanje bolezni, pri čemer na prvo vpliva pospešena nevrodegeneracija pri pospešenem poteku bolezni, druga pa je odraz akutne vnetne aktivnosti bolezni. Fenotipi multiple skleroze se razlikujejo glede na te dva parametra, zato so meritve prostornine, pa tudi drugih parametrov teh struktur pomembni biomarkerji za napovedovanje poteka bolezni in odziva na zdravljenje.
#
# ### Postopek razgradnje
#
# Dano zbirko MR slik preiskave glave bomo razgradili z uporabo nevronskih mrež. Uporabili bomo trenutno najbolj uveljavljeno arhitekturo mreže [U-Net](https://arxiv.org/abs/1505.04597), ki se uporablja za razgradnjo slik.
#
# Izvedli bomo binarno razgradnjo MR slik glave, in sicer za različne strukture:
# - **CSF=1**: likvorska tekočina
# - **GM=2**: siva možganovina
# - **CSF=3**: bela možganovina
# - **LESIONS=10**: patološke lezije
#
# Delovanje bomo preizkusili tudi na kombinacijah teh struktur, prav tako nas bo zanimalo katera modaliteta največ prispeva k kakovosti razgradnje. Pri tem bomo kot predznanje uporabili le dane referenčne razgradnje teh slik.
#
# ### Uvažanje knjižnic

# %%
from google.colab import drive
drive.mount('/content/drive/')
# %cd drive/MyDrive/Faks/AMS_colab/Analiza_slik_z_nevronskimi_mrezami
# !unzip "data.zip" -d "/content"
# !pip install SimpleITK
# Out:
# Installing collected packages: SimpleITK
# Successfully installed SimpleITK-2.3.1

# %%
import os
import sys
import random
import warnings



import numpy as np
import SimpleITK as itk
import matplotlib.pyplot as plt
from tqdm import tqdm
from sklearn.model_selection import train_test_split

from keras.models import Model, load_model
from keras.optimizers import Adam
from keras.layers import Input
from keras.layers import Dropout, Lambda
from keras.layers import Conv2D, Conv2DTranspose
from keras.layers import MaxPooling2D
from keras.layers import concatenate
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras import backend as K

import tensorflow as tf

from os.path import join
from amslib import load_mri_brain_data


seed = 42
random.seed = seed
np.random.seed = seed

# %% [markdown]
# ### Konstante in parametri

# %%
# nastavi željeno velikost slik
IMG_WIDTH = 128
IMG_HEIGHT = 128
MODALITIES = ('t1', 'flair') # 't1' and/or 'flair'
IMG_CHANNELS = len(MODALITIES)
# določi oznake
CSF, GM, WM, LESIONS = 1, 2, 3, 10
# določi delež testnih podatkov
TEST_DATA_FRACTION = 0.2

# %% [markdown]
# ## 3.1 Naloži MRI podatke in loči med učne in testne
#
# Za nalaganje podatkov bomo uporabili funkcijo **load_mri_brain_data()**, ki smo jo predstavili v prvem delu vaje in ki je dana v knjižnici **amslib**. Nato bomo z uporabo funkcije **train_test_split()** ustvarili učno in testno zbirki podatkov. Funkcija naključno priredi posamezno sliko in pripadajoče učne oznake v testno množico v predvidenem deležu, ki je podan s parametrom **test_size**. Slednji je v našem primeru določen s konstanto **TEST_DATA_FRACTION**. Učne podatke bomo uporabili za učenje modela, testne pa za preverjanje kakovosti rešitve oz. zmožnosti posploševanja naučenega modela.

# %%
X, Y_bmsk, Y_seg = load_mri_brain_data(output_size=(IMG_WIDTH, IMG_HEIGHT), modalities=('t1','flair'), data_path = '/content/data')
X_train, X_test, y_train, y_test = train_test_split(X, Y_seg , test_size=TEST_DATA_FRACTION)

print('Velikost 4D polja za učenje: {}'.format(X_train.shape))
print('Velikost 4D polja za testiranje: {}'.format(X_test.shape))
# Out:
# 100%|██████████| 647/647 [00:19<00:00, 33.02it/s]
# Velikost 4D polja za učenje: (517, 128, 128, 2)
# Velikost 4D polja za testiranje: (130, 128, 128, 2)

# %% [markdown]
# ### Določanje referenčne razgradnje
#
# Na osnovi danih referenčnih razgradenj v izhodu **Y_seg** funkcije **load_mri_brain_data()** bomo izračunali binarne maske za učenje postopka razgradnje. Za večjo učinkovitost učenja obdelujemo le 2D rezine MR slike, iz katerih ni možno določiti celotne prostornine lezij.

# %%
y_train = (y_train == WM).astype('int8') + (y_train == LESIONS).astype('int8')
y_test = (y_test == WM).astype('int8') + (y_test == LESIONS).astype('int8')

y_train.shape
# Out:
# (517, 128, 128, 1)

# %% [markdown]
# ### Izris vzorca učnih podatkov

# %%
# Check if training data looks all right
ix = random.randint(0, X_train.shape[0])
_, _, num_modalities = X_train[ix].shape

titles = [m.upper() + ' slika' for m in MODALITIES] + ['Referenčna razgradnja']
f, ax = plt.subplots(1, num_modalities+1, sharex=True, sharey=True, figsize=(20, 5))
for i in range(num_modalities):
    ax[i].imshow(X_train[ix][:,:,i], cmap='gray')
    ax[i].set_title(titles[i])
    ax[i].axis('off')
ax[-1].imshow(np.squeeze(y_train[ix]))
ax[-1].set_title(titles[-1])
# Out:
# Text(0.5, 1.0, 'Referenčna razgradnja')

# %% [markdown]
# ## 3.2 Načrtovanje in učenje U-net modela
#
# V naslednjem bloku bomo načrtali U-Net model, ki temelji na [U-Net: Convolutional Networks for Biomedical Image Segmentation](https://arxiv.org/pdf/1505.04597.pdf) in je podoben [javno dostopni implementaciji](https://github.com/jocicmarko/ultrasound-nerve-segmentation) iz tekmovanja Kaggle Ultrasound Nerve Segmentation.
#
# ![](https://lmb.informatik.uni-freiburg.de/people/ronneber/u-net/u-net-architecture.png)

# %% [markdown]
# ### Definicija modela
#
# Uporabili bomo **Functional (model API)** način definicije modela v knjižnici **Keras**. Določili bomo objekte posameznih gradnikov in jih poljubno (tj. ne nujno zaporedoma) povezali med seboj. Na koncu moramo dobiti dva objekta, kjer prvi predstavlja vhod, drugi pa izhod. S tema objektoma nato inicializiramo model s klicem konstruktorja **Model(inputs=, outputs=)**.
#
# Uporabljalli bomo že znane osnovne gradnike **Conv2D**, **MaxPooling2D**, **Dropout**, **Dense** in **Flatten**, poleg tega pa še:
# - **Conv2DTranspose**: konvolucijska plast, ki poviša velikost izhodnega polja glede na vhodno; gradniku podamo število filtrov, velikost filtrov, prostorski korak filtra (*stride*)
#
# Pri konvolucijskih plasteh **Conv2D** in **Conv2DTranspose** smo nastavili še parametra inicializacije uteži po postopku *he_normal* in dodajanje elementov *padding* za zagotavljanje ustrezne velikosti izhodnega polja. S klicem funkcije **summary()** dobimo izpis strukture in števila parametrov modela.

# %%
# ?Lambda

# %%
# vhodna plast
inputs = Input((IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS))

### BEGIN SOLUTION
s = Lambda(lambda x: x ) (inputs)
tf.cast(s, tf.float32)
print(s)
# levi del U
c1 = Conv2D(16, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (s)
c1 = Dropout(0.1) (c1)
c1 = Conv2D(16, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c1)
p1 = MaxPooling2D((2, 2)) (c1)

c2 = Conv2D(32, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (p1)
c2 = Dropout(0.1) (c2)
c2 = Conv2D(32, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c2)
p2 = MaxPooling2D((2, 2)) (c2)

c3 = Conv2D(64, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (p2)
c3 = Dropout(0.2) (c3)
c3 = Conv2D(64, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c3)
p3 = MaxPooling2D((2, 2)) (c3)

c4 = Conv2D(128, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (p3)
c4 = Dropout(0.2) (c4)
c4 = Conv2D(128, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c4)
p4 = MaxPooling2D(pool_size=(2, 2)) (c4)

c5 = Conv2D(256, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (p4)
c5 = Dropout(0.3) (c5)
c5 = Conv2D(256, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c5)

# desni del U
u6 = Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same') (c5)
u6 = concatenate([u6, c4])
c6 = Conv2D(128, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (u6)
c6 = Dropout(0.2) (c6)
c6 = Conv2D(128, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c6)

u7 = Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same') (c6)
u7 = concatenate([u7, c3])
c7 = Conv2D(64, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (u7)
c7 = Dropout(0.2) (c7)
c7 = Conv2D(64, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c7)

u8 = Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same') (c7)
u8 = concatenate([u8, c2])
c8 = Conv2D(32, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (u8)
c8 = Dropout(0.1) (c8)
c8 = Conv2D(32, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c8)

u9 = Conv2DTranspose(16, (2, 2), strides=(2, 2), padding='same') (c8)
u9 = concatenate([u9, c1], axis=3)
c9 = Conv2D(16, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (u9)
c9 = Dropout(0.1) (c9)
c9 = Conv2D(16, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c9)

# polno povezana plast z 1x1 konvolucijo
outputs = Conv2D(1, (1, 1), activation='sigmoid') (c9)

# inicializacija modela
model = Model(inputs=[inputs], outputs=[outputs])
### END SOLUTION

# povzetek modela
model.summary()
# Out:
# KerasTensor(type_spec=TensorSpec(shape=(None, 128, 128, 2), dtype=tf.float32, name=None), name='Placeholder:0', description="created by layer 'lambda'")
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 128, 128, 2)]        0         []
#
#  lambda (Lambda)             (None, 128, 128, 2)          0         ['input_1[0][0]']
#
#  conv2d (Conv2D)             (None, 128, 128, 16)         304       ['lambda[0][0]']
#
#  dropout (Dropout)           (None, 128, 128, 16)         0         ['conv2d[0][0]']
#
#  conv2d_1 (Conv2D)           (None, 128, 128, 16)         2320      ['dropout[0][0]']
#
#  max_pooling2d (MaxPooling2  (None, 64, 64, 16)           0         ['conv2d_1[0][0]']
#  D)
#
#  conv2d_2 (Conv2D)           (None, 64, 64, 32)           4640      ['max_pooling2d[0][0]']
#
#  dropout_1 (Dropout)         (None, 64, 64, 32)           0         ['conv2d_2[0][0]']
#
#  conv2d_3 (Conv2D)           (None, 64, 64, 32)           9248      ['dropout_1[0][0]']
#
#  max_pooling2d_1 (MaxPoolin  (None, 32, 32, 32)           0         ['conv2d_3[0][0]']
#  g2D)
#
#  conv2d_4 (Conv2D)           (None, 32, 32, 64)           18496     ['max_pooling2d_1[0][0]']
#
#  dropout_2 (Dropout)         (None, 32, 32, 64)           0         ['conv2d_4[0][0]']
#
#  conv2d_5 (Conv2D)           (None, 32, 32, 64)           36928     ['dropout_2[0][0]']
#
#  max_pooling2d_2 (MaxPoolin  (None, 16, 16, 64)           0         ['conv2d_5[0][0]']
#  g2D)
#
#  conv2d_6 (Conv2D)           (None, 16, 16, 128)          73856     ['max_pooling2d_2[0][0]']
#
#  dropout_3 (Dropout)         (None, 16, 16, 128)          0         ['conv2d_6[0][0]']
#
#  conv2d_7 (Conv2D)           (None, 16, 16, 128)          147584    ['dropout_3[0][0]']
#
#  max_pooling2d_3 (MaxPoolin  (None, 8, 8, 128)            0         ['conv2d_7[0][0]']
#  g2D)
#
#  conv2d_8 (Conv2D)           (None, 8, 8, 256)            295168    ['max_pooling2d_3[0][0]']
#
#  dropout_4 (Dropout)         (None, 8, 8, 256)            0         ['conv2d_8[0][0]']
#
#  conv2d_9 (Conv2D)           (None, 8, 8, 256)            590080    ['dropout_4[0][0]']
#
#  conv2d_transpose (Conv2DTr  (None, 16, 16, 128)          131200    ['conv2d_9[0][0]']
#  anspose)
#
#  concatenate (Concatenate)   (None, 16, 16, 256)          0         ['conv2d_transpose[0][0]',
#                                                                      'conv2d_7[0][0]']
#
#  conv2d_10 (Conv2D)          (None, 16, 16, 128)          295040    ['concatenate[0][0]']
#
#  dropout_5 (Dropout)         (None, 16, 16, 128)          0         ['conv2d_10[0][0]']
#
#  conv2d_11 (Conv2D)          (None, 16, 16, 128)          147584    ['dropout_5[0][0]']
#
#  conv2d_transpose_1 (Conv2D  (None, 32, 32, 64)           32832     ['conv2d_11[0][0]']
#  Transpose)
#
#  concatenate_1 (Concatenate  (None, 32, 32, 128)          0         ['conv2d_transpose_1[0][0]',
#  )                                                                   'conv2d_5[0][0]']
#
#  conv2d_12 (Conv2D)          (None, 32, 32, 64)           73792     ['concatenate_1[0][0]']
#
#  dropout_6 (Dropout)         (None, 32, 32, 64)           0         ['conv2d_12[0][0]']
#
#  conv2d_13 (Conv2D)          (None, 32, 32, 64)           36928     ['dropout_6[0][0]']
#
#  conv2d_transpose_2 (Conv2D  (None, 64, 64, 32)           8224      ['conv2d_13[0][0]']
#  Transpose)
#
#  concatenate_2 (Concatenate  (None, 64, 64, 64)           0         ['conv2d_transpose_2[0][0]',
#  )                                                                   'conv2d_3[0][0]']
#
#  conv2d_14 (Conv2D)          (None, 64, 64, 32)           18464     ['concatenate_2[0][0]']
#
#  dropout_7 (Dropout)         (None, 64, 64, 32)           0         ['conv2d_14[0][0]']
#
#  conv2d_15 (Conv2D)          (None, 64, 64, 32)           9248      ['dropout_7[0][0]']
#
#  conv2d_transpose_3 (Conv2D  (None, 128, 128, 16)         2064      ['conv2d_15[0][0]']
#  Transpose)
#
#  concatenate_3 (Concatenate  (None, 128, 128, 32)         0         ['conv2d_transpose_3[0][0]',
#  )                                                                   'conv2d_1[0][0]']
#
#  conv2d_16 (Conv2D)          (None, 128, 128, 16)         4624      ['concatenate_3[0][0]']
#
#  dropout_8 (Dropout)         (None, 128, 128, 16)         0         ['conv2d_16[0][0]']
#
#  conv2d_17 (Conv2D)          (None, 128, 128, 16)         2320      ['dropout_8[0][0]']
#
#  conv2d_18 (Conv2D)          (None, 128, 128, 1)          17        ['conv2d_17[0][0]']
#
# ==================================================================================================
# Total params: 1940961 (7.40 MB)
# Trainable params: 1940961 (7.40 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %% [markdown]
# ### Definicija kriterijskih funkcij
#
# Kriterijske funkcije lahko v obliki Python funkcij z ustreznimi vhodnimi parametri:
# - **y_true**: referenčna razgradnja ali oznaka
# - **y_pred**: z modelom določena razgradnja ali oznaka
#
# Poizkusite delovanje različnih funkcij in njihov vpliv na kakovost razgradnje.

# %%
def mean_iou(y_true, y_pred):
    prec = []
    for t in np.arange(0.5, 1.0, 0.05):
        y_pred_ = tf.to_int32(y_pred > t)
        score, up_opt = tf.metrics.mean_iou(y_true, y_pred_, 2)
        K.get_session().run(tf.local_variables_initializer())
        with tf.control_dependencies([up_opt]):
            score = tf.identity(score)
        prec.append(score)
    return K.mean(K.stack(prec), axis=0)

def iou_coef(y_true, y_pred, smooth=1):
    """
    IoU = (|X & Y|)/ (|X or Y|)
    """
    y_true = tf.cast(y_true, dtype=tf.float32)  # Cast to float32
    y_pred = tf.cast(y_pred, dtype=tf.float32)  # Cast to float32

    intersection = K.sum(K.abs(y_true * y_pred), axis=[1, 2])
    union = K.sum(y_true, [1, 2]) + K.sum(y_pred, [1, 2]) - intersection
    return (intersection + smooth) / (union + smooth)

def iou_coef_loss(y_true, y_pred):
    return -iou_coef(y_true, y_pred)

def dice_coef(y_true, y_pred):
    """
    DSC = (2*|X &amp; Y|)/ (|X| + |Y|)
    """
    smooth = 1
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

def dice_coef_loss(y_true, y_pred):
    return 1-dice_coef(y_true, y_pred)

# %% [markdown]
# ### Hiperparametri
#
# Nekaj pomembnih izpostavljenih parametrov, ki so vezani na učenje modela.

# %%
BATCH_SIZE = 16
NUM_EPOCHS = 50
LEARNING_RATE = 0.0001

# %% [markdown]
# ### Nastavitve modela za učenje
#
# Funkcija **compile()** opravi prevajanje modela v strojno kodo, ki je primerna za učinkovito izvajanje. Nekateri pomembni parametri funkcije so:
# - **optimizer**: naziv ali objekt postopka optimizacije (glej možnosti [optimizers](https://keras.io/optimizers/))
# - **loss**: naziv ali objekt kriterijske funkcije (glej možnosti [losses](https://keras.io/losses/))
# - **metrics**: seznam metrik za vrednotenje modela med učenjem in testiranjem
#
# Pomemben hiperparameter vsakega postopka optimizacije je tudi učna konstanta. V tem primeru bomo prepustili postopku optimizacije, da uporabi privzeto vrednost.

# %%
model.compile(
    optimizer=Adam(lr=LEARNING_RATE),
    loss=[iou_coef_loss],  #'binary_crossentropy'
    metrics=[dice_coef])
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.

# %% [markdown]
# ### Učenje modela

# %%
# zaženi učenje modela
earlystopper = EarlyStopping(patience=5, verbose=1)
checkpointer = ModelCheckpoint(join('models', 'model-mri-unet-seg-3.h5'), verbose=1, save_best_only=True)
results = model.fit(X_train, y_train, validation_data= (X_test, y_test), batch_size=BATCH_SIZE, epochs=NUM_EPOCHS,
                    callbacks=[earlystopper, checkpointer])
# Out:
# Epoch 1/50
# 33/33 [==============================] - ETA: 0s - loss: -0.2813 - dice_coef: 0.4373
# Epoch 1: val_loss improved from inf to -0.48596, saving model to models/model-mri-unet-seg-3.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 33/33 [==============================] - 25s 179ms/step - loss: -0.2813 - dice_coef: 0.4373 - val_loss: -0.4860 - val_dice_coef: 0.6560
# Epoch 2/50
# 32/33 [============================>.] - ETA: 0s - loss: -0.5385 - dice_coef: 0.7005
# Epoch 2: val_loss improved from -0.48596 to -0.58369, saving model to models/model-mri-unet-seg-3.h5
# 33/33 [==============================] - 2s 66ms/step - loss: -0.5389 - dice_coef: 0.7016 - val_loss: -0.5837 - val_dice_coef: 0.7397
# Epoch 3/50
# 33/33 [==============================] - ETA: 0s - loss: -0.6189 - dice_coef: 0.7652
# Epoch 3: val_loss improved from -0.58369 to -0.67085, saving model to models/model-mri-unet-seg-3.h5
# 33/33 [==============================] - 2s 61ms/step - loss: -0.6189 - dice_coef: 0.7652 - val_loss: -0.6708 - val_dice_coef: 0.8064
# Epoch 4/50
# 32/33 [============================>.] - ETA: 0s - loss: -0.7101 - dice_coef: 0.8300
# Epoch 4: val_loss improved from -0.67085 to -0.75862, saving model to models/model-mri-unet-seg-3.h5
# 33/33 [==============================] - 2s 61ms/step - loss: -0.7105 - dice_coef: 0.8308 - val_loss: -0.7586 - val_dice_coef: 0.8662
# Epoch 5/50
# 32/33 [============================>.] - ETA: 0s - loss: -0.7715 - dice_coef: 0.8707
# Epoch 5: val_loss improved from -0.75862 to -0.79274, saving model to models/model-mri-unet-seg-3.h5
# 33/33 [==============================] - 2s 60ms/step - loss: -0.7715 - dice_coef: 0.8708 - val_loss: -0.7927 - val_dice_coef: 0.8871
# Epoch 6/50
# 32/33 [============================>.] - ETA: 0s - loss: -0.7989 - dice_coef: 0.8880
# Epoch 6: val_loss improved from -0.79274 to -0.82167, saving model to models/model-mri-unet-seg-3.h5
# 33/33 [==============================] - 2s 60ms/step - loss: -0.7991 - dice_coef: 0.8884 - val_loss: -0.8217 - val_dice_coef: 0.9049
# Epoch 7/50
# 33/33 [==============================] - ETA: 0s - loss: -0.8127 - dice_coef: 0.8967
# Epoch 7: val_loss improved from -0.82167 to -0.82771, saving model to models/model-mri-unet-seg-3.h5
# 33/33 [==============================] - 2s 58ms/step - loss: -0.8127 - dice_coef: 0.8967 - val_loss: -0.8277 - val_dice_coef: 0.9079
# Epoch 8/50
# 33/33 [==============================] - ETA: 0s - loss: -0.8216 - dice_coef: 0.9017
# Epoch 8: val_loss improved from -0.82771 to -0.83379, saving model to models/model-mri-unet-seg-3.h5
# 33/33 [==============================] - 2s 62ms/step - loss: -0.8216 - dice_coef: 0.9017 - val_loss: -0.8338 - val_dice_coef: 0.9116
# Epoch 9/50
# 32/33 [============================>.] - ETA: 0s - loss: -0.8313 - dice_coef: 0.9076
# Epoch 9: val_loss improved from -0.83379 to -0.84167, saving model to models/model-mri-unet-seg-3.h5
# 33/33 [==============================] - 2s 64ms/step - loss: -0.8315 - dice_coef: 0.9080 - val_loss: -0.8417 - val_dice_coef: 0.9159
# Epoch 10/50
# 33/33 [==============================] - ETA: 0s - loss: -0.8373 - dice_coef: 0.9115
# Epoch 10: val_loss did not improve from -0.84167
# 33/33 [==============================] - 2s 56ms/step - loss: -0.8373 - dice_coef: 0.9115 - val_loss: -0.8415 - val_dice_coef: 0.9157
# Epoch 11/50
# 32/33 [============================>.] - ETA: 0s - loss: -0.8427 - dice_coef: 0.9145
# Epoch 11: val_loss improved from -0.84167 to -0.85317, saving model to models/model-mri-unet-seg-3.h5
# 33/33 [==============================] - 2s 60ms/step - loss: -0.8428 - dice_coef: 0.9147 - val_loss: -0.8532 - val_dice_coef: 0.9226
# Epoch 12/50
# 32/33 [============================>.] - ETA: 0s - loss: -0.8460 - dice_coef: 0.9164
# Epoch 12: val_loss improved from -0.85317 to -0.85434, saving model to models/model-mri-unet-seg-3.h5
# 33/33 [==============================] - 2s 60ms/step - loss: -0.8460 - dice_coef: 0.9164 - val_loss: -0.8543 - val_dice_coef: 0.9233
# Epoch 13/50
# 32/33 [============================>.] - ETA: 0s - loss: -0.8496 - dice_coef: 0.9185
# Epoch 13: val_loss improved from -0.85434 to -0.85648, saving model to models/model-mri-unet-seg-3.h5
# 33/33 [==============================] - 2s 59ms/step - loss: -0.8496 - dice_coef: 0.9187 - val_loss: -0.8565 - val_dice_coef: 0.9242
# Epoch 14/50
# 33/33 [==============================] - ETA: 0s - loss: -0.8538 - dice_coef: 0.9207
# Epoch 14: val_loss improved from -0.85648 to -0.85849, saving model to models/model-mri-unet-seg-3.h5
# 33/33 [==============================] - 2s 61ms/step - loss: -0.8538 - dice_coef: 0.9207 - val_loss: -0.8585 - val_dice_coef: 0.9255
# Epoch 15/50
# 33/33 [==============================] - ETA: 0s - loss: -0.8552 - dice_coef: 0.9220
# Epoch 15: val_loss improved from -0.85849 to -0.85939, saving model to models/model-mri-unet-seg-3.h5
# 33/33 [==============================] - 2s 59ms/step - loss: -0.8552 - dice_coef: 0.9220 - val_loss: -0.8594 - val_dice_coef: 0.9259
# Epoch 16/50
# 32/33 [============================>.] - ETA: 0s - loss: -0.8580 - dice_coef: 0.9234
# Epoch 16: val_loss improved from -0.85939 to -0.86211, saving model to models/model-mri-unet-seg-3.h5
# 33/33 [==============================] - 2s 63ms/step - loss: -0.8580 - dice_coef: 0.9234 - val_loss: -0.8621 - val_dice_coef: 0.9277
# Epoch 17/50
# 32/33 [============================>.] - ETA: 0s - loss: -0.8603 - dice_coef: 0.9248
# Epoch 17: val_loss improved from -0.86211 to -0.86614, saving model to models/model-mri-unet-seg-3.h5
# 33/33 [==============================] - 2s 66ms/step - loss: -0.8604 - dice_coef: 0.9249 - val_loss: -0.8661 - val_dice_coef: 0.9302
# Epoch 18/50
# 32/33 [============================>.] - ETA: 0s - loss: -0.8611 - dice_coef: 0.9251
# Epoch 18: val_loss improved from -0.86614 to -0.87039, saving model to models/model-mri-unet-seg-3.h5
# 33/33 [==============================] - 2s 65ms/step - loss: -0.8612 - dice_coef: 0.9254 - val_loss: -0.8704 - val_dice_coef: 0.9324
# Epoch 19/50
# 32/33 [============================>.] - ETA: 0s - loss: -0.8633 - dice_coef: 0.9265
# Epoch 19: val_loss did not improve from -0.87039
# 33/33 [==============================] - 2s 55ms/step - loss: -0.8634 - dice_coef: 0.9266 - val_loss: -0.8637 - val_dice_coef: 0.9286
# Epoch 20/50
# 32/33 [============================>.] - ETA: 0s - loss: -0.8657 - dice_coef: 0.9279
# Epoch 20: val_loss improved from -0.87039 to -0.87241, saving model to models/model-mri-unet-seg-3.h5
# 33/33 [==============================] - 2s 60ms/step - loss: -0.8658 - dice_coef: 0.9280 - val_loss: -0.8724 - val_dice_coef: 0.9335
# Epoch 21/50
# 32/33 [============================>.] - ETA: 0s - loss: -0.8669 - dice_coef: 0.9286
# Epoch 21: val_loss did not improve from -0.87241
# 33/33 [==============================] - 2s 54ms/step - loss: -0.8669 - dice_coef: 0.9287 - val_loss: -0.8698 - val_dice_coef: 0.9319
# Epoch 22/50
# 32/33 [============================>.] - ETA: 0s - loss: -0.8687 - dice_coef: 0.9297
# Epoch 22: val_loss did not improve from -0.87241
# 33/33 [==============================] - 2s 55ms/step - loss: -0.8687 - dice_coef: 0.9296 - val_loss: -0.8705 - val_dice_coef: 0.9320
# Epoch 23/50
# 32/33 [============================>.] - ETA: 0s - loss: -0.8696 - dice_coef: 0.9301
# Epoch 23: val_loss improved from -0.87241 to -0.87535, saving model to models/model-mri-unet-seg-3.h5
# 33/33 [==============================] - 2s 60ms/step - loss: -0.8696 - dice_coef: 0.9301 - val_loss: -0.8753 - val_dice_coef: 0.9349
# Epoch 24/50
# 32/33 [============================>.] - ETA: 0s - loss: -0.8707 - dice_coef: 0.9308
# Epoch 24: val_loss did not improve from -0.87535
# 33/33 [==============================] - 2s 55ms/step - loss: -0.8707 - dice_coef: 0.9307 - val_loss: -0.8726 - val_dice_coef: 0.9333
# Epoch 25/50
# 32/33 [============================>.] - ETA: 0s - loss: -0.8716 - dice_coef: 0.9313
# Epoch 25: val_loss improved from -0.87535 to -0.87564, saving model to models/model-mri-unet-seg-3.h5
# 33/33 [==============================] - 2s 66ms/step - loss: -0.8713 - dice_coef: 0.9307 - val_loss: -0.8756 - val_dice_coef: 0.9350
# Epoch 26/50
# 32/33 [============================>.] - ETA: 0s - loss: -0.8719 - dice_coef: 0.9314
# Epoch 26: val_loss did not improve from -0.87564
# 33/33 [==============================] - 2s 57ms/step - loss: -0.8717 - dice_coef: 0.9310 - val_loss: -0.8702 - val_dice_coef: 0.9320
# Epoch 27/50
# 32/33 [============================>.] - ETA: 0s - loss: -0.8734 - dice_coef: 0.9323
# Epoch 27: val_loss improved from -0.87564 to -0.87785, saving model to models/model-mri-unet-seg-3.h5
# 33/33 [==============================] - 2s 62ms/step - loss: -0.8735 - dice_coef: 0.9326 - val_loss: -0.8779 - val_dice_coef: 0.9363
# Epoch 28/50
# 32/33 [============================>.] - ETA: 0s - loss: -0.8744 - dice_coef: 0.9329
# Epoch 28: val_loss did not improve from -0.87785
# 33/33 [==============================] - 2s 54ms/step - loss: -0.8744 - dice_coef: 0.9330 - val_loss: -0.8696 - val_dice_coef: 0.9313
# Epoch 29/50
# 32/33 [============================>.] - ETA: 0s - loss: -0.8756 - dice_coef: 0.9336
# Epoch 29: val_loss did not improve from -0.87785
# 33/33 [==============================] - 2s 54ms/step - loss: -0.8757 - dice_coef: 0.9337 - val_loss: -0.8772 - val_dice_coef: 0.9359
# Epoch 30/50
# 32/33 [============================>.] - ETA: 0s - loss: -0.8769 - dice_coef: 0.9343
# Epoch 30: val_loss did not improve from -0.87785
# 33/33 [==============================] - 2s 54ms/step - loss: -0.8769 - dice_coef: 0.9344 - val_loss: -0.8715 - val_dice_coef: 0.9323
# Epoch 31/50
# 32/33 [============================>.] - ETA: 0s - loss: -0.8768 - dice_coef: 0.9342
# Epoch 31: val_loss improved from -0.87785 to -0.87836, saving model to models/model-mri-unet-seg-3.h5
# 33/33 [==============================] - 2s 62ms/step - loss: -0.8766 - dice_coef: 0.9337 - val_loss: -0.8784 - val_dice_coef: 0.9367
# Epoch 32/50
# 32/33 [============================>.] - ETA: 0s - loss: -0.8773 - dice_coef: 0.9346
# Epoch 32: val_loss improved from -0.87836 to -0.88087, saving model to models/model-mri-unet-seg-3.h5
# 33/33 [==============================] - 2s 65ms/step - loss: -0.8774 - dice_coef: 0.9347 - val_loss: -0.8809 - val_dice_coef: 0.9381
# Epoch 33/50
# 32/33 [============================>.] - ETA: 0s - loss: -0.8801 - dice_coef: 0.9363
# Epoch 33: val_loss improved from -0.88087 to -0.88105, saving model to models/model-mri-unet-seg-3.h5
# 33/33 [==============================] - 2s 65ms/step - loss: -0.8791 - dice_coef: 0.9337 - val_loss: -0.8811 - val_dice_coef: 0.9381
# Epoch 34/50
# 32/33 [============================>.] - ETA: 0s - loss: -0.8800 - dice_coef: 0.9360
# Epoch 34: val_loss did not improve from -0.88105
# 33/33 [==============================] - 2s 58ms/step - loss: -0.8800 - dice_coef: 0.9360 - val_loss: -0.8785 - val_dice_coef: 0.9365
# Epoch 35/50
# 32/33 [============================>.] - ETA: 0s - loss: -0.8814 - dice_coef: 0.9368
# Epoch 35: val_loss improved from -0.88105 to -0.88312, saving model to models/model-mri-unet-seg-3.h5
# 33/33 [==============================] - 2s 64ms/step - loss: -0.8813 - dice_coef: 0.9367 - val_loss: -0.8831 - val_dice_coef: 0.9391
# Epoch 36/50
# 32/33 [============================>.] - ETA: 0s - loss: -0.8800 - dice_coef: 0.9360
# Epoch 36: val_loss did not improve from -0.88312
# 33/33 [==============================] - 2s 56ms/step - loss: -0.8800 - dice_coef: 0.9360 - val_loss: -0.8815 - val_dice_coef: 0.9382
# Epoch 37/50
# 32/33 [============================>.] - ETA: 0s - loss: -0.8827 - dice_coef: 0.9375
# Epoch 37: val_loss improved from -0.88312 to -0.88326, saving model to models/model-mri-unet-seg-3.h5
# 33/33 [==============================] - 2s 63ms/step - loss: -0.8825 - dice_coef: 0.9372 - val_loss: -0.8833 - val_dice_coef: 0.9395
# Epoch 38/50
# 32/33 [============================>.] - ETA: 0s - loss: -0.8825 - dice_coef: 0.9375
# Epoch 38: val_loss did not improve from -0.88326
# 33/33 [==============================] - 2s 55ms/step - loss: -0.8826 - dice_coef: 0.9378 - val_loss: -0.8814 - val_dice_coef: 0.9383
# Epoch 39/50
# 32/33 [============================>.] - ETA: 0s - loss: -0.8837 - dice_coef: 0.9381
# Epoch 39: val_loss improved from -0.88326 to -0.88543, saving model to models/model-mri-unet-seg-3.h5
# 33/33 [==============================] - 2s 63ms/step - loss: -0.8836 - dice_coef: 0.9380 - val_loss: -0.8854 - val_dice_coef: 0.9405
# Epoch 40/50
# 32/33 [============================>.] - ETA: 0s - loss: -0.8844 - dice_coef: 0.9386
# Epoch 40: val_loss did not improve from -0.88543
# 33/33 [==============================] - 2s 57ms/step - loss: -0.8844 - dice_coef: 0.9385 - val_loss: -0.8853 - val_dice_coef: 0.9404
# Epoch 41/50
# 32/33 [============================>.] - ETA: 0s - loss: -0.8857 - dice_coef: 0.9393
# Epoch 41: val_loss did not improve from -0.88543
# 33/33 [==============================] - 2s 59ms/step - loss: -0.8857 - dice_coef: 0.9393 - val_loss: -0.8818 - val_dice_coef: 0.9385
# Epoch 42/50
# 32/33 [============================>.] - ETA: 0s - loss: -0.8861 - dice_coef: 0.9395
# Epoch 42: val_loss did not improve from -0.88543
# 33/33 [==============================] - 2s 58ms/step - loss: -0.8862 - dice_coef: 0.9397 - val_loss: -0.8794 - val_dice_coef: 0.9367
# Epoch 43/50
# 32/33 [============================>.] - ETA: 0s - loss: -0.8862 - dice_coef: 0.9396
# Epoch 43: val_loss improved from -0.88543 to -0.88596, saving model to models/model-mri-unet-seg-3.h5
# 33/33 [==============================] - 2s 64ms/step - loss: -0.8863 - dice_coef: 0.9397 - val_loss: -0.8860 - val_dice_coef: 0.9407
# Epoch 44/50
# 32/33 [============================>.] - ETA: 0s - loss: -0.8874 - dice_coef: 0.9402
# Epoch 44: val_loss did not improve from -0.88596
# 33/33 [==============================] - 2s 54ms/step - loss: -0.8873 - dice_coef: 0.9401 - val_loss: -0.8856 - val_dice_coef: 0.9406
# Epoch 45/50
# 32/33 [============================>.] - ETA: 0s - loss: -0.8878 - dice_coef: 0.9405
# Epoch 45: val_loss did not improve from -0.88596
# 33/33 [==============================] - 2s 55ms/step - loss: -0.8879 - dice_coef: 0.9406 - val_loss: -0.8814 - val_dice_coef: 0.9382
# Epoch 46/50
# 32/33 [============================>.] - ETA: 0s - loss: -0.8880 - dice_coef: 0.9405
# Epoch 46: val_loss did not improve from -0.88596
# 33/33 [==============================] - 2s 56ms/step - loss: -0.8879 - dice_coef: 0.9404 - val_loss: -0.8848 - val_dice_coef: 0.9401
# Epoch 47/50
# 32/33 [============================>.] - ETA: 0s - loss: -0.8877 - dice_coef: 0.9404
# Epoch 47: val_loss did not improve from -0.88596
# 33/33 [==============================] - 2s 56ms/step - loss: -0.8875 - dice_coef: 0.9402 - val_loss: -0.8822 - val_dice_coef: 0.9385
# Epoch 48/50
# 33/33 [==============================] - ETA: 0s - loss: -0.8879 - dice_coef: 0.9406
# Epoch 48: val_loss did not improve from -0.88596
# 33/33 [==============================] - 2s 55ms/step - loss: -0.8879 - dice_coef: 0.9406 - val_loss: -0.8830 - val_dice_coef: 0.9392
# Epoch 48: early stopping

# %% [markdown]
# ## 3.3 Vrednotenje razgradnje
#
# Kakovost razgradnje bomo vrednotili **kvalitativno** s prikazom in primerjavo pridobljene in referenčne razgradnje ter **kvantitativno** z izračunom Diceovega podobnostnega koeficienta.
#
# ### Naloži model in izračunaj razgradnje na učni in testni zbirki
#
# Razgradnja, ki jo bo U-net model vrnil v izhodnem polju *ni binarna*, kot pričakujemo, ampak so dane zvezne vrednosti v razponu [0, 1], ki predstavljajo posteriorno verjetnost oznak. V našem primeru so oznake:
# - **0**: ozadje
# - **1**: struktura zanimanja, kot smo jo določili z referenčnimi razgradnjami pri učenju

# %%
# naloži model
model = load_model(join('models', 'model-mri-unet-seg-3.h5'),
                   custom_objects={'dice_coef': dice_coef, 'dice_coef_loss': dice_coef_loss,
                                  'iou_coef_loss': iou_coef_loss})



# opravi razgradnjo na učni in testni zbirki
preds_train = model.predict(X_train[:int(X_train.shape[0]*0.9)], verbose=1)
preds_test = model.predict(X_test, verbose=1)

# dobljene vrednosti
preds_train_t = (preds_train > 0.5).astype(np.uint8)
preds_test_t = (preds_test > 0.5).astype(np.uint8)
# Out:
# 15/15 [==============================] - 2s 58ms/step
# 5/5 [==============================] - 0s 19ms/step

# %% [markdown]
# ### Kvalitativno: kakovost razgradnje na učnih vzorcih (ali sploh deluje?)

# %%
# preveri kakovost razgradnje na učnih vzorcih (sanity check)
ix = random.randint(0, len(preds_train_t))
_, _, num_modalities = X_train[ix].shape

titles = [m.upper() + ' slika' for m in MODALITIES] + ['Referenčna razgradnja', 'Razgradnja U-net']
f, ax = plt.subplots(1, num_modalities+2, sharex=True, sharey=True, figsize=(20, 5))
for i in range(num_modalities):
    ax[i].imshow(X_train[ix][:,:,i], cmap='gray')
    ax[i].set_title(titles[i])
    ax[i].axis('off')
# prikaži referenčno razgradnjo
ax[-2].imshow(np.squeeze(y_train[ix]))
ax[-2].set_title(titles[-2])
ax[-2].axis('off')
# prikaži razgradnjo z U-net
ax[-1].imshow(np.squeeze(preds_train_t[ix]))
ax[-1].set_title(titles[-1])
ax[-1].axis('off')

plt.show()

# %% [markdown]
# ### Kvalitativno: kakovost razgradnje na testnih vzorcih (zmožnost posploševanja)

# %%
# preveri kakovost razgradnje na naključno izbranih testnih vzorcih
ix = random.randint(0, len(preds_test_t))
_, _, num_modalities = X_test[ix].shape

titles = [m.upper() + ' slika' for m in MODALITIES] + ['Referenčna razgradnja', 'Razgradnja U-net']
f, ax = plt.subplots(1, num_modalities+2, sharex=True, sharey=True, figsize=(20, 5))
for i in range(num_modalities):
    ax[i].imshow(X_test[ix][:,:,i], cmap='gray')
    ax[i].set_title(titles[i])
    ax[i].axis('off')
# prikaži referenčno razgradnjo
ax[-2].imshow(np.squeeze(y_test[ix]))
ax[-2].set_title(titles[-2])
ax[-2].axis('off')
# prikaži razgradnjo z U-net
ax[-1].imshow(np.squeeze(preds_test_t[ix]))
ax[-1].set_title(titles[-1])
ax[-1].axis('off')

plt.show()

# %% [markdown]
# ### Kvantitativno: povprečna vrednost Diceovega koeficienta na vseh testnih slikah

# %%
def dice(result, reference):
    result = np.atleast_1d(result.astype(np.bool))
    reference = np.atleast_1d(reference.astype(np.bool))
    intersection = np.count_nonzero(result & reference)
    size_i1 = np.count_nonzero(result)
    size_i2 = np.count_nonzero(reference)

    try:
        dc = 2. * intersection / float(size_i1 + size_i2)
    except ZeroDivisionError:
        dc = 0.0
    return dc

test_dice = []
for i in range(y_test.shape[0]):
    test_dice.append(dice(preds_test_t[i].flatten(), y_test[i].flatten()))

print('Povprečna vrednost Diceovega koeficienta na testni zbirki: ', np.mean(test_dice))
# Out:
# Povprečna vrednost Diceovega koeficienta na testni zbirki:  0.9383786867243676
# <ipython-input-25-fe6c6c05fec8>:2: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   result = np.atleast_1d(result.astype(np.bool))
# <ipython-input-25-fe6c6c05fec8>:3: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   reference = np.atleast_1d(reference.astype(np.bool))
