# %% [markdown]
# # 2. Razvrščanje slik z nevronskimi mrežami
#
# ## Motivacija
#
# Postopke načrtovanja, učenja in vrednotenja nevronskih mrež bomo najprej spoznali za namen razvrščanja MR slik glave v posamezne razrede, in sicer za bolnike z multiplo sklerozo. Cilj naloge bo, da le na podlagi sivinskih vrednosti slik razvrstimo bolnike v dve skupini:
#
# - tiste z veliko prostornino in
# - tiste z majhno prostornino patoloških lezij.
#
# Motivacija za tovrstno razvrščanje pri bolnikih z multiplo sklerozo je tudi klinično motivirana. Namreč, prostornina lezij odraža breme bolezni, pri čemer večje lezije v splošnem predstavljajo večje breme bolezni za bolnika. S takim modelom lahko naprimer ob diagnozi bolezni ločimo bolnike v dve skupini, tiste s pričakovanim težjim potekom bolezni (več lezij, večja prostornina lezij) in tiste z blažjim potekom bolezni (manj lezij, manjša prostornina lezij). Prvi skupini bolnikov s tem nudimo bolj potentna zdravila že v zgodnji fazi bolezni, kar lahko upočasni razvoj bolezni.
#
# ## Programska orodja
#
# Nevronske mreže bomo načrtovali s Python knjižnico Keras. Ta visokonivojska knjižnica predstavlja le programski vmesnik (API=application program interface) nizkonivojskih Python knjižnic za strojno učenje, med njimi najbolj popularni sta Tensorflow in Theano. Slednji knjižnici omogočata učenje model nevronskih mrež z uporabo masovno paralelnih grafičnih procesnih enot (GPU=graphic processing unit) in temeljita na klicih nižjenivojskih knjižnico kot je cuDNN in CUDA proizvajalca GPU enot NVidia. Pri tej nalogi se ne bomo ukvarjali z običajno zahtevnim nameščanjem vseh potrebnih knjižnic. Dobra navodila za ta namen dobite na spletnih straneh omenjenih knjižnic.

# %% [markdown]
# ## Uvažanje knjižnic

# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/Faks/AMS_colab/Analiza_slik_z_nevronskimi_mrezami
# !pwd
# prompt: unzip to conent
# !unzip -q /content/drive/MyDrive/Faks/AMS_colab/Analiza_slik_z_nevronskimi_mrezami/data.zip -d /content/
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/Faks/AMS_colab/Analiza_slik_z_nevronskimi_mrezami
# /content/drive/MyDrive/Faks/AMS_colab/Analiza_slik_z_nevronskimi_mrezami

# %%
# !pip install SimpleITK
# Out:
# Requirement already satisfied: SimpleITK in /usr/local/lib/python3.10/dist-packages (2.4.0)

# %%
from __future__ import print_function
import os
import random
import numpy as np
import matplotlib.pyplot as plt
import SimpleITK as itk
import tensorflow as tf

import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras import backend as K
from keras.callbacks import Callback

from os.path import exists, join
from sklearn.model_selection import train_test_split
from amslib import load_mri_brain_data

#config = tf.compat.v1.ConfigProto
#session = tf.compat.v1.Session()

seed = 42
random.seed = seed
np.random.seed = seed

# %%
CSF, GM, WM, LESIONS = 1, 2, 3, 10
TEST_DATA_FRACTION = 0.33
IMAGE_SIZE = (64, 64)
MODALITIES = ('t1',) # ('t1','flair') ali ('flair',) ali ('t1',)
NUM_CLASSES = 2 # binarno razvrščanje (lahko tudi več kategorij oz. oznak)

# %% [markdown]
# # 2.1 Naloži MRI podatke in loči med učne in testne
# Za nalaganje podatkov bomo uporabili funkcijo load_mri_brain_data(), ki smo jo predstavili v prvem delu vaje in ki je dana v knjižnici amslib. Nato bomo z uporabo funkcije train_test_split() ustvarili učno in testno zbirki podatkov. Funkcija naključno priredi posamezno sliko in pripadajoče učne oznake v testno množico v predvidenem deležu, ki je podan s parametrom test_size. Slednji je v našem primeru določen s konstanto TEST_DATA_FRACTION. Učne podatke bomo uporabili za učenje modela, testne pa za preverjanje kakovosti rešitve oz. zmožnosti posploševanja naučenega modela.

# %%
X, Y_bmsk, Y_seg = load_mri_brain_data(output_size=IMAGE_SIZE, modalities=MODALITIES, data_path = '/content/data_/')
X_train, X_test, y_train, y_test = train_test_split(X, Y_seg , test_size=TEST_DATA_FRACTION)

print('Velikost učne zbirke slik: {}'.format(X_train.shape))
print('Velikost testne zbirke slik: {}'.format(X_test.shape))
# Out:
# 100%|██████████| 647/647 [00:43<00:00, 14.84it/s]
# Velikost učne zbirke slik: (433, 64, 64, 1)
# Velikost testne zbirke slik: (214, 64, 64, 1)

# %% [markdown]
# ## Določanje mejnega praga za velikost lezij
# Na osnovi danih referenčnih razgradenj v izhodu Y_seg funkcije load_mri_brain_data() bomo določili pražno vrednost velikosti lezij. Za večjo učinkovitost učenja obdelujemo le 2D rezine MR slike, iz katerih ni možno določiti celotne prostornine lezij. Zato bomo pražno vrednost določili tako, da bo število slik z majhno in veliko prostornino lezij približno enako. Enakomerna zastopanost razredov oznak (manjše/večje) običajno koristno pripomore h kakovosti naučenih modelov.

# %%
# določimo mejno velikost lezij
LESION_SIZE_THRESHOLD = 30

# ANALIZA UČNEGA SETA PODATKOV
# izračunaj velikost maske lezij za vsako sliko
lesion_voxels = np.sum(np.sum(np.squeeze(y_train==LESIONS),axis=-1),axis=-1)

large_lesions = np.count_nonzero(lesion_voxels>LESION_SIZE_THRESHOLD)
small_lesions = np.count_nonzero(lesion_voxels<=LESION_SIZE_THRESHOLD)
print('Število slik z veliko prostornino lezij: {:d}'.format(large_lesions))
print('Število slik z malo prostornino lezij: {:d}'.format(small_lesions))

# pretvori vektor oznak razreda v binarno matriko oznak tipa 1-k
Y_train = keras.utils.to_categorical((lesion_voxels>LESION_SIZE_THRESHOLD).astype('int'))
# Out:
# Število slik z veliko prostornino lezij: 208
# Število slik z malo prostornino lezij: 225

# %%
# ANALIZA TESTNEGA SETA PODATKOV
# izračunaj velikost maske lezij za vsako sliko
lesion_voxels = np.sum(np.sum(np.squeeze(y_test==LESIONS),axis=-1),axis=-1)

large_lesions = np.count_nonzero(lesion_voxels>LESION_SIZE_THRESHOLD)
small_lesions = np.count_nonzero(lesion_voxels<=LESION_SIZE_THRESHOLD)
print('Število slik z veliko prostornino lezij: {:d}'.format(large_lesions))
print('Število slik z malo prostornino lezij: {:d}'.format(small_lesions))

# pretvori vektor oznak razreda v binarno matriko oznak tipa 1-k
Y_test = keras.utils.to_categorical((lesion_voxels>LESION_SIZE_THRESHOLD).astype('int'))
# Out:
# Število slik z veliko prostornino lezij: 78
# Število slik z malo prostornino lezij: 136

# %% [markdown]
# # 2.2 Načrtovanje in učenje modela razvrščevalnika
# ## Definicija modela
# Knjižnica Keras omogoča dva načina definicije modela: Sequential in Functional (model API). Prvi način je sekvenčni, kjer inicializiramo prazen model in nato dodajamo plasti sekvenčno oz. zaporedoma eno za drugo s funkcijo add(). Pri drugem pa najprej definiramo objekte posameznih gradnikov in jih poljubno (tj. ne nujno zaporedoma) povežemo med seboj. Na koncu moramo dobiti dva objekta, kjer prvi predstavlja vhod, drugi pa izhod. S tema objektoma nato inicializiramo model s klicem konstruktorja Model(inputs=, outputs=).
#
# Pri tej nalogi bomo uporabili sekvenčni način definicije modela, pri nalogi z razgradnjo pa funkcijski način. Osnovni gradniki in njihovi parametri so na voljo s klici konstruktorjev teh gradnikov, npr.:
#
# - Conv2D: konvolucijska plast, kjer podamo število filtrov, velikost filtrov in aktivacijsko funkcijo (v prvi plasti podamo še velikost vhodnih podatkov)
# - MaxPooling: plast združevanja sosednjih odzivov, s katero zmanjšamo velikost odzivov
# - Dropout: naključno ugašanje povezav modela s podanim deležem
# - Dense: polno povezana plast s parametrom števila skritih nevronov in aktivacijsko funkcijo
# - Flatten: pretvori poljubno vhodno polje v vektor (tipično pred Dense plastjo)
#
# Tipično uporabljene aktivacijske funkcije so sigmoid, relu, tanh, softmax (glej možnosti aktivacijskih funkcij). S klicem funkcije summary() dobimo izpis strukture in števila parametrov modela.

# %%
# ?Lambd

# %%
model = Sequential()
model.add(Conv2D(32, kernel_size=(3, 3),
                 activation='relu',
                 input_shape=X_train.shape[1:]))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(NUM_CLASSES, activation='softmax'))

# povzetek strukture modela in števila parametrov
model.summary()
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 62, 62, 32)          │             320 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 60, 60, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 30, 30, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 30, 30, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 57600)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 128)                 │       7,372,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 2)                   │             258 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 7,392,002 (28.20 MB)
#  Trainable params: 7,392,002 (28.20 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## Hiperparametri
#
# Nekaj pomembnih izpostavljenih parametrov, ki so vezani na učenje modela.

# %%
BATCH_SIZE = 16
NUM_EPOCHS = 100
LEARNING_RATE = 1e-3

# %% [markdown]
# ## Nastavitve modela za učenje
# Funkcija compile() opravi prevajanje modela v strojno kodo, ki je primerna za učinkovito izvajanje. Nekateri pomembni parametri funkcije so:
#
# - optimizer: naziv ali objekt postopka optimizacije (glej možnosti optimizers)
# - loss: naziv ali objekt kriterijske funkcije (glej možnosti losses)
# - metrics: seznam metrik za vrednotenje modela med učenjem in testiranjem
#
# Pomemben hiperparameter vsakega postopka optimizacije je tudi učna konstanta (konstanta LEARNING_RATE), ki jo podamo s parametrom lr.

# %%
model.compile(loss=keras.losses.categorical_crossentropy,
              optimizer=keras.optimizers.Adam(learning_rate=LEARNING_RATE), # Adadelta, RMSprop, SGD,...
              metrics=['accuracy'])

# %% [markdown]
# # Učenje modela
# Učenje modela zaženemo s funkcijo fit(), ki ima več parametrov:
#
# - x: numpy polje učnih podatkov
# - y: numpy polje učnih oznak
# - batch_size: število vzorcev za izračun gradienta uteži modela
# - epochs: število ponovitev učenja, pri čemer ena epoha predstavlja posodobitve modela z uporabo vseh vhodnih podatkov
# - verbose: stopnja podrobnosti izpisovanju poteka učenja (0-brez,1-prikaz napredka,2-ena vrstica na epoho)
# - validation_data: par numpy polj s testnimi podatki in oznakami, za spremljanje zmožnosti posploševanja modela
# - callbacks: seznam prilagojenih povratnih klicev za diagnostiko poteka učenja
#
# Med učenjem modela lahko spremljate potek učenja z orodjem Tensorboard (osnovni meni Jupyter > New > Tensorboard, prikazno okno odprete pod Jupyter > Running > Tensorboard).

# %%
# pripravi izpis kriterijskih funkcij za Tensorboard
run_count = 0
while exists('./graphs/' + str(run_count)):
    run_count += 1

tbCallBack = keras.callbacks.TensorBoard(
    log_dir='./graphs/' + str(run_count),
    histogram_freq=0,
    write_graph=True,
    write_images=True)

class TestCallback(Callback):
    def __init__(self, test_data):
        self.test_data = test_data

    def on_epoch_end(self, epoch, logs={}):
        x, y = self.test_data
        loss, acc = self.model.evaluate(x, y, verbose=0)
        print('\nTesting loss: {}, acc: {}\n'.format(loss, acc))

# zaženi učenje modela
model.fit(X_train, Y_train,
          batch_size=BATCH_SIZE,
          epochs=NUM_EPOCHS,
          verbose=1,
          validation_data=(X_test, Y_test),
          callbacks=[tbCallBack, TestCallback((X_test, Y_test))])
# Out:
# Epoch 1/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 262ms/step - accuracy: 0.5328 - loss: 0.7028
# Testing loss: 0.6667206883430481, acc: 0.6355140209197998
#
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 18s 373ms/step - accuracy: 0.5329 - loss: 0.7025 - val_accuracy: 0.6355 - val_loss: 0.6667
# Epoch 2/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 358ms/step - accuracy: 0.5970 - loss: 0.6713
# Testing loss: 0.6516510248184204, acc: 0.7009345889091492
#
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 21s 456ms/step - accuracy: 0.5956 - loss: 0.6716 - val_accuracy: 0.7009 - val_loss: 0.6517
# Epoch 3/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 257ms/step - accuracy: 0.6295 - loss: 0.6600
# Testing loss: 0.6505507230758667, acc: 0.5934579372406006
#
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 17s 332ms/step - accuracy: 0.6295 - loss: 0.6597 - val_accuracy: 0.5935 - val_loss: 0.6506
# Epoch 4/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 310ms/step - accuracy: 0.6751 - loss: 0.6173
# Testing loss: 0.6609986424446106, acc: 0.5841121673583984
#
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 12s 408ms/step - accuracy: 0.6745 - loss: 0.6178 - val_accuracy: 0.5841 - val_loss: 0.6610
# Epoch 5/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step - accuracy: 0.6856 - loss: 0.6254
# Testing loss: 0.640741765499115, acc: 0.6962617039680481
#
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 19s 345ms/step - accuracy: 0.6861 - loss: 0.6252 - val_accuracy: 0.6963 - val_loss: 0.6407
# Epoch 6/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 284ms/step - accuracy: 0.7281 - loss: 0.5388
# Testing loss: 0.6229316592216492, acc: 0.7056074738502502
#
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 11s 382ms/step - accuracy: 0.7263 - loss: 0.5401 - val_accuracy: 0.7056 - val_loss: 0.6229
# Epoch 7/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 288ms/step - accuracy: 0.6854 - loss: 0.5950
# Testing loss: 0.6368085741996765, acc: 0.6869158744812012
#
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 20s 388ms/step - accuracy: 0.6855 - loss: 0.5941 - val_accuracy: 0.6869 - val_loss: 0.6368
# Epoch 8/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 366ms/step - accuracy: 0.7225 - loss: 0.5793
# Testing loss: 0.6729230284690857, acc: 0.6915887594223022
#
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 23s 464ms/step - accuracy: 0.7231 - loss: 0.5784 - val_accuracy: 0.6916 - val_loss: 0.6729
# Epoch 9/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 257ms/step - accuracy: 0.7107 - loss: 0.5477
# Testing loss: 0.6051458120346069, acc: 0.7056074738502502
#
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 17s 355ms/step - accuracy: 0.7096 - loss: 0.5484 - val_accuracy: 0.7056 - val_loss: 0.6051
# Epoch 10/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 295ms/step - accuracy: 0.7677 - loss: 0.5057
# Testing loss: 0.6340305209159851, acc: 0.7383177280426025
#
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 11s 392ms/step - accuracy: 0.7675 - loss: 0.5057 - val_accuracy: 0.7383 - val_loss: 0.6340
# Epoch 11/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 293ms/step - accuracy: 0.7790 - loss: 0.4842
# Testing loss: 0.6529205441474915, acc: 0.7196261882781982
#
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 20s 392ms/step - accuracy: 0.7779 - loss: 0.4854 - val_accuracy: 0.7196 - val_loss: 0.6529
# Epoch 12/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step - accuracy: 0.7594 - loss: 0.4606
# Testing loss: 0.6623495221138, acc: 0.7149532437324524
#
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 10s 344ms/step - accuracy: 0.7597 - loss: 0.4611 - val_accuracy: 0.7150 - val_loss: 0.6623
# Epoch 13/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 309ms/step - accuracy: 0.7729 - loss: 0.4694
# Testing loss: 0.6725784540176392, acc: 0.7149532437324524
#
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 12s 406ms/step - accuracy: 0.7734 - loss: 0.4691 - val_accuracy: 0.7150 - val_loss: 0.6726
# Epoch 14/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - accuracy: 0.8058 - loss: 0.4485
# Testing loss: 0.6966291666030884, acc: 0.7056074738502502
#
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 11s 401ms/step - accuracy: 0.8060 - loss: 0.4477 - val_accuracy: 0.7056 - val_loss: 0.6966
# Epoch 15/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 266ms/step - accuracy: 0.8239 - loss: 0.3711
# Testing loss: 0.6825494766235352, acc: 0.7289719581604004
#
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 20s 363ms/step - accuracy: 0.8238 - loss: 0.3713 - val_accuracy: 0.7290 - val_loss: 0.6825
# Epoch 16/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step - accuracy: 0.7862 - loss: 0.4721
# Testing loss: 0.7591683268547058, acc: 0.6869158744812012
#
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 22s 428ms/step - accuracy: 0.7870 - loss: 0.4708 - val_accuracy: 0.6869 - val_loss: 0.7592
# Epoch 17/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 286ms/step - accuracy: 0.7795 - loss: 0.4557
# Testing loss: 0.7452772855758667, acc: 0.7196261882781982
#
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 19s 362ms/step - accuracy: 0.7809 - loss: 0.4536 - val_accuracy: 0.7196 - val_loss: 0.7453
# Epoch 18/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 328ms/step - accuracy: 0.8438 - loss: 0.3350
# Testing loss: 0.7452636361122131, acc: 0.7289719581604004
#
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 12s 426ms/step - accuracy: 0.8442 - loss: 0.3349 - val_accuracy: 0.7290 - val_loss: 0.7453
# Epoch 19/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 249ms/step - accuracy: 0.8613 - loss: 0.3428
# Testing loss: 0.7506701946258545, acc: 0.7056074738502502
#
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 18s 346ms/step - accuracy: 0.8615 - loss: 0.3420 - val_accuracy: 0.7056 - val_loss: 0.7507
# Epoch 20/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 322ms/step - accuracy: 0.8721 - loss: 0.2967
# Testing loss: 0.7353799343109131, acc: 0.7616822719573975
#
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 12s 420ms/step - accuracy: 0.8718 - loss: 0.2967 - val_accuracy: 0.7617 - val_loss: 0.7354
# Epoch 21/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 255ms/step - accuracy: 0.9015 - loss: 0.2371
# Testing loss: 0.7513255476951599, acc: 0.7663551568984985
#
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 19s 354ms/step - accuracy: 0.9011 - loss: 0.2376 - val_accuracy: 0.7664 - val_loss: 0.7513
# Epoch 22/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 282ms/step - accuracy: 0.9119 - loss: 0.2085
# Testing loss: 0.9451131820678711, acc: 0.65887850522995
#
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 10s 356ms/step - accuracy: 0.9120 - loss: 0.2086 - val_accuracy: 0.6589 - val_loss: 0.9451
# Epoch 23/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 333ms/step - accuracy: 0.9222 - loss: 0.2016
# Testing loss: 0.8146870136260986, acc: 0.7476635575294495
#
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 12s 430ms/step - accuracy: 0.9222 - loss: 0.2017 - val_accuracy: 0.7477 - val_loss: 0.8147
# Epoch 24/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 266ms/step - accuracy: 0.9261 - loss: 0.1796
# Testing loss: 0.8730581402778625, acc: 0.7336448431015015
#
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 19s 364ms/step - accuracy: 0.9264 - loss: 0.1792 - val_accuracy: 0.7336 - val_loss: 0.8731
# Epoch 25/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 338ms/step - accuracy: 0.9426 - loss: 0.1510
# Testing loss: 0.8387451767921448, acc: 0.7523364424705505
#
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 22s 414ms/step - accuracy: 0.9425 - loss: 0.1511 - val_accuracy: 0.7523 - val_loss: 0.8387
# Epoch 26/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 295ms/step - accuracy: 0.9172 - loss: 0.2069
# Testing loss: 0.8133630752563477, acc: 0.672897219657898
#
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 20s 392ms/step - accuracy: 0.9165 - loss: 0.2082 - val_accuracy: 0.6729 - val_loss: 0.8134
# Epoch 27/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 290ms/step - accuracy: 0.9052 - loss: 0.2007
# Testing loss: 0.8144188523292542, acc: 0.7289719581604004
#
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 20s 389ms/step - accuracy: 0.9055 - loss: 0.2011 - val_accuracy: 0.7290 - val_loss: 0.8144
# Epoch 28/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 400ms/step - accuracy: 0.9568 - loss: 0.1597
# Testing loss: 0.8231215476989746, acc: 0.7757009267807007
#
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 24s 529ms/step - accuracy: 0.9566 - loss: 0.1599 - val_accuracy: 0.7757 - val_loss: 0.8231
# Epoch 29/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.9288 - loss: 0.1913
# Testing loss: 0.800140380859375, acc: 0.7523364424705505
#
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 15s 330ms/step - accuracy: 0.9287 - loss: 0.1911 - val_accuracy: 0.7523 - val_loss: 0.8001
# Epoch 30/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - accuracy: 0.9546 - loss: 0.1470
# Testing loss: 0.9452922940254211, acc: 0.7383177280426025
#
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 12s 421ms/step - accuracy: 0.9549 - loss: 0.1463 - val_accuracy: 0.7383 - val_loss: 0.9453
# Epoch 31/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 254ms/step - accuracy: 0.9579 - loss: 0.1337
# Testing loss: 1.0564771890640259, acc: 0.6682242751121521
#
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 18s 347ms/step - accuracy: 0.9576 - loss: 0.1340 - val_accuracy: 0.6682 - val_loss: 1.0565
# Epoch 32/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 282ms/step - accuracy: 0.9469 - loss: 0.1533
# Testing loss: 1.0901216268539429, acc: 0.6915887594223022
#
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 11s 379ms/step - accuracy: 0.9469 - loss: 0.1527 - val_accuracy: 0.6916 - val_loss: 1.0901
# Epoch 33/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 320ms/step - accuracy: 0.9494 - loss: 0.1323
# Testing loss: 1.0144511461257935, acc: 0.7383177280426025
#
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 21s 418ms/step - accuracy: 0.9495 - loss: 0.1316 - val_accuracy: 0.7383 - val_loss: 1.0145
# Epoch 34/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 295ms/step - accuracy: 0.9578 - loss: 0.1137
# Testing loss: 1.003767490386963, acc: 0.7102803587913513
#
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 19s 369ms/step - accuracy: 0.9579 - loss: 0.1137 - val_accuracy: 0.7103 - val_loss: 1.0038
# Epoch 35/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 282ms/step - accuracy: 0.9664 - loss: 0.1002
# Testing loss: 1.110025405883789, acc: 0.7616822719573975
#
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 21s 382ms/step - accuracy: 0.9665 - loss: 0.0998 - val_accuracy: 0.7617 - val_loss: 1.1100
# Epoch 36/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 265ms/step - accuracy: 0.9604 - loss: 0.1016
# Testing loss: 1.280869722366333, acc: 0.672897219657898
#
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 10s 362ms/step - accuracy: 0.9607 - loss: 0.1015 - val_accuracy: 0.6729 - val_loss: 1.2809
# Epoch 37/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 334ms/step - accuracy: 0.9555 - loss: 0.1059
# Testing loss: 1.043094515800476, acc: 0.7570093274116516
#
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 12s 432ms/step - accuracy: 0.9556 - loss: 0.1054 - val_accuracy: 0.7570 - val_loss: 1.0431
# Epoch 38/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 244ms/step - accuracy: 0.9713 - loss: 0.0915
# Testing loss: 1.1768410205841064, acc: 0.7383177280426025
#
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 18s 344ms/step - accuracy: 0.9716 - loss: 0.0909 - val_accuracy: 0.7383 - val_loss: 1.1768
# Epoch 39/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 274ms/step - accuracy: 0.9840 - loss: 0.0553
# Testing loss: 1.2925015687942505, acc: 0.7056074738502502
#
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 10s 327ms/step - accuracy: 0.9838 - loss: 0.0555 - val_accuracy: 0.7056 - val_loss: 1.2925
# Epoch 40/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step - accuracy: 0.9858 - loss: 0.0673
# Testing loss: 1.1199662685394287, acc: 0.7710280418395996
#
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 13s 427ms/step - accuracy: 0.9856 - loss: 0.0671 - val_accuracy: 0.7710 - val_loss: 1.1200
# Epoch 41/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 274ms/step - accuracy: 0.9880 - loss: 0.0485
# Testing loss: 1.258528232574463, acc: 0.7336448431015015
#
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 10s 366ms/step - accuracy: 0.9879 - loss: 0.0487 - val_accuracy: 0.7336 - val_loss: 1.2585
# Epoch 42/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 264ms/step - accuracy: 0.9913 - loss: 0.0591
# Testing loss: 1.2898966073989868, acc: 0.7383177280426025
#
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 9s 318ms/step - accuracy: 0.9913 - loss: 0.0589 - val_accuracy: 0.7383 - val_loss: 1.2899
# Epoch 43/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 0.9715 - loss: 0.0767
# Testing loss: 1.2621326446533203, acc: 0.7429906725883484
#
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 13s 429ms/step - accuracy: 0.9716 - loss: 0.0762 - val_accuracy: 0.7430 - val_loss: 1.2621
# Epoch 44/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 310ms/step - accuracy: 0.9755 - loss: 0.0635
# Testing loss: 1.2858073711395264, acc: 0.7943925261497498
#
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 11s 408ms/step - accuracy: 0.9754 - loss: 0.0637 - val_accuracy: 0.7944 - val_loss: 1.2858
# Epoch 45/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - accuracy: 0.9925 - loss: 0.0439
# Testing loss: 1.2471002340316772, acc: 0.7663551568984985
#
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 21s 421ms/step - accuracy: 0.9923 - loss: 0.0440 - val_accuracy: 0.7664 - val_loss: 1.2471
# Epoch 46/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 255ms/step - accuracy: 0.9899 - loss: 0.0411
# Testing loss: 1.3341690301895142, acc: 0.7429906725883484
#
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 18s 354ms/step - accuracy: 0.9900 - loss: 0.0411 - val_accuracy: 0.7430 - val_loss: 1.3342
# Epoch 47/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 285ms/step - accuracy: 0.9893 - loss: 0.0417
# Testing loss: 1.3436062335968018, acc: 0.7383177280426025
#
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 11s 383ms/step - accuracy: 0.9894 - loss: 0.0415 - val_accuracy: 0.7383 - val_loss: 1.3436
# Epoch 48/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 313ms/step - accuracy: 0.9966 - loss: 0.0355
# Testing loss: 1.5463873147964478, acc: 0.6869158744812012
#
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 22s 437ms/step - accuracy: 0.9965 - loss: 0.0354 - val_accuracy: 0.6869 - val_loss: 1.5464
# Epoch 49/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step - accuracy: 0.9657 - loss: 0.0837
# Testing loss: 1.3952875137329102, acc: 0.7523364424705505
#
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 10s 345ms/step - accuracy: 0.9661 - loss: 0.0833 - val_accuracy: 0.7523 - val_loss: 1.3953
# Epoch 50/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 285ms/step - accuracy: 0.9806 - loss: 0.0462
# Testing loss: 1.6696890592575073, acc: 0.6682242751121521
#
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 11s 361ms/step - accuracy: 0.9805 - loss: 0.0464 - val_accuracy: 0.6682 - val_loss: 1.6697
# Epoch 51/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 337ms/step - accuracy: 0.9767 - loss: 0.0808
# Testing loss: 1.2110514640808105, acc: 0.7663551568984985
#
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 12s 436ms/step - accuracy: 0.9767 - loss: 0.0808 - val_accuracy: 0.7664 - val_loss: 1.2111
# Epoch 52/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 283ms/step - accuracy: 0.9970 - loss: 0.0494
# Testing loss: 1.5569961071014404, acc: 0.7056074738502502
#
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 11s 384ms/step - accuracy: 0.9970 - loss: 0.0489 - val_accuracy: 0.7056 - val_loss: 1.5570
# Epoch 53/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 258ms/step - accuracy: 1.0000 - loss: 0.0233
# Testing loss: 1.5479891300201416, acc: 0.7196261882781982
#
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 9s 311ms/step - accuracy: 1.0000 - loss: 0.0233 - val_accuracy: 0.7196 - val_loss: 1.5480
# Epoch 54/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 340ms/step - accuracy: 0.9955 - loss: 0.0255
# Testing loss: 1.7178187370300293, acc: 0.6822429895401001
#
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 12s 438ms/step - accuracy: 0.9953 - loss: 0.0255 - val_accuracy: 0.6822 - val_loss: 1.7178
# Epoch 55/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 317ms/step - accuracy: 0.9966 - loss: 0.0211
# Testing loss: 1.4678257703781128, acc: 0.7850467562675476
#
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 12s 418ms/step - accuracy: 0.9965 - loss: 0.0213 - val_accuracy: 0.7850 - val_loss: 1.4678
# Epoch 56/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - accuracy: 0.9995 - loss: 0.0221
# Testing loss: 1.5677330493927002, acc: 0.7523364424705505
#
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 20s 399ms/step - accuracy: 0.9994 - loss: 0.0223 - val_accuracy: 0.7523 - val_loss: 1.5677
# Epoch 57/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 320ms/step - accuracy: 0.9874 - loss: 0.0362
# Testing loss: 1.3648343086242676, acc: 0.7383177280426025
#
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 11s 399ms/step - accuracy: 0.9872 - loss: 0.0367 - val_accuracy: 0.7383 - val_loss: 1.3648
# Epoch 58/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 303ms/step - accuracy: 0.9940 - loss: 0.0386
# Testing loss: 1.6204420328140259, acc: 0.7102803587913513
#
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 20s 380ms/step - accuracy: 0.9940 - loss: 0.0384 - val_accuracy: 0.7103 - val_loss: 1.6204
# Epoch 59/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 340ms/step - accuracy: 0.9994 - loss: 0.0167
# Testing loss: 1.5975571870803833, acc: 0.7523364424705505
#
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 12s 416ms/step - accuracy: 0.9993 - loss: 0.0167 - val_accuracy: 0.7523 - val_loss: 1.5976
# Epoch 60/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 243ms/step - accuracy: 1.0000 - loss: 0.0158
# Testing loss: 1.794832706451416, acc: 0.7056074738502502
#
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 10s 343ms/step - accuracy: 1.0000 - loss: 0.0157 - val_accuracy: 0.7056 - val_loss: 1.7948
# Epoch 61/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 262ms/step - accuracy: 1.0000 - loss: 0.0114
# Testing loss: 1.680164098739624, acc: 0.7336448431015015
#
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 10s 339ms/step - accuracy: 1.0000 - loss: 0.0115 - val_accuracy: 0.7336 - val_loss: 1.6802
# Epoch 62/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 340ms/step - accuracy: 0.9995 - loss: 0.0141
# Testing loss: 1.8111181259155273, acc: 0.7336448431015015
#
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 12s 437ms/step - accuracy: 0.9994 - loss: 0.0142 - val_accuracy: 0.7336 - val_loss: 1.8111
# Epoch 63/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 259ms/step - accuracy: 0.9975 - loss: 0.0184
# Testing loss: 1.7618191242218018, acc: 0.7102803587913513
#
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 18s 356ms/step - accuracy: 0.9976 - loss: 0.0183 - val_accuracy: 0.7103 - val_loss: 1.7618
# Epoch 64/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 316ms/step - accuracy: 0.9916 - loss: 0.0320
# Testing loss: 1.6599338054656982, acc: 0.7570093274116516
#
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 11s 392ms/step - accuracy: 0.9914 - loss: 0.0320 - val_accuracy: 0.7570 - val_loss: 1.6599
# Epoch 65/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.9933 - loss: 0.0233
# Testing loss: 1.6844375133514404, acc: 0.7616822719573975
#
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 19s 347ms/step - accuracy: 0.9933 - loss: 0.0234 - val_accuracy: 0.7617 - val_loss: 1.6844
# Epoch 66/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 274ms/step - accuracy: 0.9950 - loss: 0.0295
# Testing loss: 1.729317307472229, acc: 0.7336448431015015
#
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 10s 349ms/step - accuracy: 0.9950 - loss: 0.0295 - val_accuracy: 0.7336 - val_loss: 1.7293
# Epoch 67/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 334ms/step - accuracy: 0.9926 - loss: 0.0383
# Testing loss: 1.7839041948318481, acc: 0.7663551568984985
#
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 12s 432ms/step - accuracy: 0.9925 - loss: 0.0387 - val_accuracy: 0.7664 - val_loss: 1.7839
# Epoch 68/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 267ms/step - accuracy: 0.9631 - loss: 0.0653
# Testing loss: 1.4966235160827637, acc: 0.7289719581604004
#
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 10s 367ms/step - accuracy: 0.9634 - loss: 0.0649 - val_accuracy: 0.7290 - val_loss: 1.4966
# Epoch 69/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 252ms/step - accuracy: 0.9868 - loss: 0.0447
# Testing loss: 1.4404442310333252, acc: 0.7616822719573975
#
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 10s 349ms/step - accuracy: 0.9866 - loss: 0.0448 - val_accuracy: 0.7617 - val_loss: 1.4404
# Epoch 70/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 327ms/step - accuracy: 0.9870 - loss: 0.0384
# Testing loss: 1.5191679000854492, acc: 0.7523364424705505
#
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 12s 425ms/step - accuracy: 0.9869 - loss: 0.0384 - val_accuracy: 0.7523 - val_loss: 1.5192
# Epoch 71/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 249ms/step - accuracy: 0.9967 - loss: 0.0243
# Testing loss: 1.8812801837921143, acc: 0.7710280418395996
#
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 18s 348ms/step - accuracy: 0.9966 - loss: 0.0242 - val_accuracy: 0.7710 - val_loss: 1.8813
# Epoch 72/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 295ms/step - accuracy: 1.0000 - loss: 0.0118
# Testing loss: 1.877219319343567, acc: 0.7803738117218018
#
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 10s 371ms/step - accuracy: 1.0000 - loss: 0.0117 - val_accuracy: 0.7804 - val_loss: 1.8772
# Epoch 73/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 344ms/step - accuracy: 0.9997 - loss: 0.0066
# Testing loss: 1.9592026472091675, acc: 0.7429906725883484
#
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 12s 442ms/step - accuracy: 0.9997 - loss: 0.0067 - val_accuracy: 0.7430 - val_loss: 1.9592
# Epoch 74/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 278ms/step - accuracy: 1.0000 - loss: 0.0090
# Testing loss: 2.066540479660034, acc: 0.7336448431015015
#
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 19s 377ms/step - accuracy: 1.0000 - loss: 0.0090 - val_accuracy: 0.7336 - val_loss: 2.0665
# Epoch 75/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 1.0000 - loss: 0.0069
# Testing loss: 1.9670569896697998, acc: 0.7570093274116516
#
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 12s 429ms/step - accuracy: 1.0000 - loss: 0.0069 - val_accuracy: 0.7570 - val_loss: 1.9671
# Epoch 76/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 259ms/step - accuracy: 0.9902 - loss: 0.0372
# Testing loss: 1.8198975324630737, acc: 0.7102803587913513
#
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 19s 357ms/step - accuracy: 0.9903 - loss: 0.0367 - val_accuracy: 0.7103 - val_loss: 1.8199
# Epoch 77/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 314ms/step - accuracy: 0.9997 - loss: 0.0105
# Testing loss: 1.818182349205017, acc: 0.7616822719573975
#
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 11s 391ms/step - accuracy: 0.9997 - loss: 0.0106 - val_accuracy: 0.7617 - val_loss: 1.8182
# Epoch 78/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 279ms/step - accuracy: 1.0000 - loss: 0.0063
# Testing loss: 2.14760422706604, acc: 0.7102803587913513
#
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 20s 378ms/step - accuracy: 1.0000 - loss: 0.0063 - val_accuracy: 0.7103 - val_loss: 2.1476
# Epoch 79/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 262ms/step - accuracy: 0.9983 - loss: 0.0064
# Testing loss: 1.8796995878219604, acc: 0.7523364424705505
#
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 10s 360ms/step - accuracy: 0.9983 - loss: 0.0064 - val_accuracy: 0.7523 - val_loss: 1.8797
# Epoch 80/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 339ms/step - accuracy: 0.9906 - loss: 0.0163
# Testing loss: 1.7475438117980957, acc: 0.7429906725883484
#
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 12s 437ms/step - accuracy: 0.9907 - loss: 0.0163 - val_accuracy: 0.7430 - val_loss: 1.7475
# Epoch 81/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 257ms/step - accuracy: 1.0000 - loss: 0.0057
# Testing loss: 1.9714680910110474, acc: 0.7476635575294495
#
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 18s 357ms/step - accuracy: 1.0000 - loss: 0.0057 - val_accuracy: 0.7477 - val_loss: 1.9715
# Epoch 82/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 298ms/step - accuracy: 0.9932 - loss: 0.0091
# Testing loss: 2.0278918743133545, acc: 0.7383177280426025
#
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 11s 396ms/step - accuracy: 0.9933 - loss: 0.0091 - val_accuracy: 0.7383 - val_loss: 2.0279
# Epoch 83/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 308ms/step - accuracy: 1.0000 - loss: 0.0064
# Testing loss: 2.1345858573913574, acc: 0.7289719581604004
#
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 21s 407ms/step - accuracy: 1.0000 - loss: 0.0064 - val_accuracy: 0.7290 - val_loss: 2.1346
# Epoch 84/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 255ms/step - accuracy: 1.0000 - loss: 0.0042
# Testing loss: 2.021703004837036, acc: 0.7663551568984985
#
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 10s 353ms/step - accuracy: 1.0000 - loss: 0.0042 - val_accuracy: 0.7664 - val_loss: 2.0217
# Epoch 85/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 313ms/step - accuracy: 0.9897 - loss: 0.0261
# Testing loss: 1.6106444597244263, acc: 0.7289719581604004
#
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 12s 412ms/step - accuracy: 0.9896 - loss: 0.0264 - val_accuracy: 0.7290 - val_loss: 1.6106
# Epoch 86/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 0.9872 - loss: 0.0345
# Testing loss: 1.5296030044555664, acc: 0.7429906725883484
#
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 12s 428ms/step - accuracy: 0.9873 - loss: 0.0348 - val_accuracy: 0.7430 - val_loss: 1.5296
# Epoch 87/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 254ms/step - accuracy: 0.9928 - loss: 0.0347
# Testing loss: 1.7377572059631348, acc: 0.7757009267807007
#
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 18s 352ms/step - accuracy: 0.9928 - loss: 0.0346 - val_accuracy: 0.7757 - val_loss: 1.7378
# Epoch 88/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 325ms/step - accuracy: 0.9969 - loss: 0.0135
# Testing loss: 1.8803541660308838, acc: 0.7383177280426025
#
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 12s 423ms/step - accuracy: 0.9969 - loss: 0.0136 - val_accuracy: 0.7383 - val_loss: 1.8804
# Epoch 89/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 260ms/step - accuracy: 1.0000 - loss: 0.0053
# Testing loss: 2.061530590057373, acc: 0.7383177280426025
#
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 19s 360ms/step - accuracy: 1.0000 - loss: 0.0053 - val_accuracy: 0.7383 - val_loss: 2.0615
# Epoch 90/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 284ms/step - accuracy: 0.9928 - loss: 0.0171
# Testing loss: 1.8326447010040283, acc: 0.7476635575294495
#
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 10s 360ms/step - accuracy: 0.9929 - loss: 0.0169 - val_accuracy: 0.7477 - val_loss: 1.8326
# Epoch 91/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 334ms/step - accuracy: 1.0000 - loss: 0.0049
# Testing loss: 1.916835904121399, acc: 0.7710280418395996
#
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 12s 431ms/step - accuracy: 1.0000 - loss: 0.0049 - val_accuracy: 0.7710 - val_loss: 1.9168
# Epoch 92/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 286ms/step - accuracy: 0.9998 - loss: 0.0098
# Testing loss: 2.1552417278289795, acc: 0.7242990732192993
#
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 11s 383ms/step - accuracy: 0.9998 - loss: 0.0100 - val_accuracy: 0.7243 - val_loss: 2.1552
# Epoch 93/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 337ms/step - accuracy: 0.9849 - loss: 0.0386
# Testing loss: 1.8377066850662231, acc: 0.7289719581604004
#
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 21s 413ms/step - accuracy: 0.9849 - loss: 0.0386 - val_accuracy: 0.7290 - val_loss: 1.8377
# Epoch 94/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 258ms/step - accuracy: 0.9978 - loss: 0.0172
# Testing loss: 1.7737187147140503, acc: 0.7570093274116516
#
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 19s 357ms/step - accuracy: 0.9977 - loss: 0.0174 - val_accuracy: 0.7570 - val_loss: 1.7737
# Epoch 95/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 292ms/step - accuracy: 0.9998 - loss: 0.0283
# Testing loss: 1.8164867162704468, acc: 0.7476635575294495
#
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 11s 390ms/step - accuracy: 0.9998 - loss: 0.0280 - val_accuracy: 0.7477 - val_loss: 1.8165
# Epoch 96/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step - accuracy: 0.9993 - loss: 0.0133
# Testing loss: 2.118647336959839, acc: 0.7009345889091492
#
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 20s 384ms/step - accuracy: 0.9992 - loss: 0.0134 - val_accuracy: 0.7009 - val_loss: 2.1186
# Epoch 97/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 328ms/step - accuracy: 0.9883 - loss: 0.0361
# Testing loss: 1.9371542930603027, acc: 0.7242990732192993
#
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 21s 404ms/step - accuracy: 0.9885 - loss: 0.0356 - val_accuracy: 0.7243 - val_loss: 1.9372
# Epoch 98/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 255ms/step - accuracy: 1.0000 - loss: 0.0059
# Testing loss: 2.100482225418091, acc: 0.7383177280426025
#
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 19s 341ms/step - accuracy: 1.0000 - loss: 0.0059 - val_accuracy: 0.7383 - val_loss: 2.1005
# Epoch 99/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 284ms/step - accuracy: 0.9996 - loss: 0.0068
# Testing loss: 2.0076546669006348, acc: 0.7616822719573975
#
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 12s 382ms/step - accuracy: 0.9995 - loss: 0.0068 - val_accuracy: 0.7617 - val_loss: 2.0077
# Epoch 100/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 335ms/step - accuracy: 1.0000 - loss: 0.0059
# Testing loss: 2.2498085498809814, acc: 0.7289719581604004
#
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 12s 432ms/step - accuracy: 1.0000 - loss: 0.0059 - val_accuracy: 0.7290 - val_loss: 2.2498

# %% [markdown]
# ## Shranjevanje modela

# %%
# shrani model v lokalno mapo
model.save_weights(join('models','lesion-classification-modalities[{}].h5'.format('+'.join(MODALITIES))))
print('Model je shranjen na disk!')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-44-e60ff8a9dd5b> in <cell line: 2>()
#       1 # shrani model v lokalno mapo
# ----> 2 model.save_weights(join('models','lesion-classification-modalities[{}].h5'.format('+'.join(MODALITIES))))
#       3 print('Model je shranjen na disk!')
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     120             # To get the full stack trace, call:
#     121             # `keras.config.disable_traceback_filtering()`
# --> 122             raise e.with_traceback(filtered_tb) from None
#     123         finally:
#     124             del filtered_tb
#
# /usr/local/lib/python3.10/dist-packages/keras/src/saving/saving_api.py in save_weights(model, filepath, overwrite, **kwargs)
#     215 def save_weights(model, filepath, overwrite=True, **kwargs):
#     216     if not str(filepath).endswith(".weights.h5"):
# --> 217         raise ValueError(
#     218             "The filename must end in `.weights.h5`. "
#     219             f"Received: filepath={filepath}"
#
# ValueError: The filename must end in `.weights.h5`. Received: filepath=models/lesion-classification-modalities[t1].h5

# %% [markdown]
# # Primerjava vrednosti kriterijskih funkcij med učno in testno zbirko
# Primerjava med kriterijskimi funkcijami na učni in testni zbirki nam omogoča zaznavanje prenasičenja učenja. Prenasičenje preprosto pomeni, da se je model razvrščevalnika specializiral za razvrščanje učnih podatkov, s čimer pa sam razvrščevalnik izgubi sposobnost posploševanja na novih, še nevidenih zbirkah podatkov.
#
# Prenasičenje zaznamo v primeru, da se vrednosti bistveno razlikujejo med učno in testno zbirko. Za zanesljivo zaznavanje prenasičenja je smiselno pogledati tudi poteke vrednosti kriterijskih funkcij v odvisnosti od epoh. V trenutnem okolju lahko potek kriterijskih funkcij, že med učenjem modela, prikažete z orodjem Tensorboard (osnovni meni Jupyter > New > Tensorboard, prikazno okno odprete pod Jupyter > Running > Tensorboard).

# %%
score = model.evaluate(X_train, Y_train, verbose=0)
print('Učna zbirka')
print('\tloss:', score[0])
print('\taccuracy:', score[1])
score = model.evaluate(X_test, Y_test, verbose=0)
print('Testna zbirka')
print('\tloss:', score[0])
print('\taccuracy:', score[1])

# %% [markdown]
# ## Vrednotenje na posameznih slikah
# Spodnja koda na testnih primerih z naučenim modelom določi oznako vhodne slike, nato prikaže vhodno sliko in pa pripadajočo razgradnjo. Izpiše se oznaka (0/1) in pa število vokslov, ki pripadajo oznaki LESIONS v referenčni razgradnji vhodne slike s pražno vrednostjo LESION_SIZE_THRESHOLD.

# %%
# inicializiraj spremenljivko idx
if 'idx' not in locals():
    idx = 0

# izberi indeks testnega znaka in prikaži
idx = idx+1
idx = np.mod(idx, X_test.shape[0])
mod_img = X_test[idx,:,:,:len(MODALITIES)]
seg_img = y_test[idx,:,:,0]
_, img_rows, img_cols, num_modalities = X_test.shape

# izvedi predikcijo in prikaži oznako
p = model.predict(np.reshape(X_test[idx,:,:,:len(MODALITIES)], [1, img_rows, img_cols, num_modalities]))
print('Predikcija oznake z modelom: {:d}'.format(np.argmax(p)))
print('Število vokslov lezij (>prag): {} (>{})'.format(np.sum(seg_img==LESIONS), LESION_SIZE_THRESHOLD))
t_or_f = not np.logical_xor(np.argmax(p)>0, np.sum(seg_img==LESIONS)>LESION_SIZE_THRESHOLD)
print('=> Razvščanje {} PRAVILNO!'.format(('JE' if t_or_f else 'NI')))

# prikaži podatke
f, ax = plt.subplots(1, len(MODALITIES)+1, sharex=True, sharey=True, figsize = (20,5))
for i in range(len(MODALITIES)):
    ax[i].imshow(mod_img[:,:,i], cmap='gray')
    ax[i].set_title(MODALITIES[i].upper() + ' slika')
    ax[i].axis('off')

ax[-1].imshow(seg_img)
ax[-1].set_title('Razgradnja')
ax[-1].axis('off')

plt.show()

# %% [markdown]
# ## Vrednotenje kakovosti razvrščanja
# Kakovost razvrščanja lahko vrednotimo po različnih kriterijih in metodologijah, npr. z uporabo elementov kontingenčne tabele, izračunom izpeljanih metrik kot je občutljivost in specifičnost, z ROC (=reciever operating characteristic) krivuljami, ipd. V spodnjem primeru bomo izračunali število pravilno razvrščenih (TP+TN) in število nepravilno razvrščenih (FP+FN) testnih vzorcev in jih prikazali glede na referenčno vrednost, tj. število vokslov iz danih referenčnih razgradenj lezij.

# %%
p = model.predict(X_test)
num_voxels = np.sum(
    np.reshape(y_test==LESIONS,
               (y_test.shape[0], np.prod(y_test.shape[1:]))),
    axis=-1)
p_true = np.argmax(Y_test, axis=-1)
p_est = np.argmax(p, axis=-1)
idx_true = p_est==p_true

print('Število pravilno razvrščenih (TP+TN): {}'.format(np.count_nonzero(idx_true)))
print('Število napačno razvrščenih (FP+FN): {}'.format(np.count_nonzero(~idx_true)))

plt.plot(num_voxels[idx_true], p_est[idx_true], c='g', marker='o', linewidth=0)
plt.plot(num_voxels[~idx_true], p_est[~idx_true], c='r', marker='o', linewidth=0)
plt.plot([LESION_SIZE_THRESHOLD, LESION_SIZE_THRESHOLD], [0.0, 1.0], c='k')
